# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from collections import defaultdict

import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.utils.data as data_utils
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso
import sklearn
from torch.utils.data.sampler import SubsetRandomSampler

import sys,os
sys.path.append(os.path.abspath("/mnt/home/yjo10/ceph/CAMELS/MIEST/utils/"))
from imp import reload 
# Change in mymodule/'
import vib_utils
reload(vib_utils)
from vib_utils import *
import mist_utils
reload(mist_utils)
from mist_utils import *

import warnings
warnings.filterwarnings('ignore')

# Device Config
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = 'cpu' # temporarily
# Fix random seeds for reproducibility
seed = 73
#torch.manual_seed(seed)
#np.random.seed(seed)a

# %%
fname = "test"
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname, beta=1e-1, gamma=1e0, test_auc=True)

# %%
fname = "search/TNG+SIMBA_HI_beta_0.01_gamma_0.01"
mist = MIST(sim=["TNG","SIMBA"],field='HI', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname)
mist.test_on(sims="ASTRID", fname="0.01")
# Out:
# HI
# $\Omega_m$: MSE=0.003, % error=15.882%, R2 score=0.750 bias=-0.064
# $\sigma_8$: MSE=0.041, % error=20.196%, R2 score=-2.109 bias=0.176

# %%
fname = "search/TNG+SIMBA_HI_beta_1.0_gamma_1.0"
mist = MIST(sim=["TNG","SIMBA"],field='HI', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname)
mist.test_on(sims="ASTRID", fname="1.0")
# Out:
# HI
# $\Omega_m$: MSE=0.005, % error=19.783%, R2 score=0.616 bias=-0.154
# $\sigma_8$: MSE=0.026, % error=15.266%, R2 score=-0.941 bias=0.104

# %%
fname = "search/TNG+SIMBA_HI_beta_0.1_gamma_0.1"
mist = MIST(sim=["TNG","SIMBA"],field='HI', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname)
mist.test_on(sims="ASTRID", fname="0.1")
# Out:
# HI
# $\Omega_m$: MSE=0.007, % error=23.330%, R2 score=0.511 bias=-0.215
# $\sigma_8$: MSE=0.028, % error=15.629%, R2 score=-1.063 bias=0.114

# %%
fname = "search/TNG+SIMBA_HI_beta_10_gamma_10"
mist = MIST(sim=["TNG","SIMBA"],field='HI', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname)
mist.test_on(sims="ASTRID", fname="10")
# Out:
# HI
# $\Omega_m$: MSE=0.004, % error=17.164%, R2 score=0.735 bias=-0.146
# $\sigma_8$: MSE=0.041, % error=20.373%, R2 score=-2.080 bias=0.176

# %%
fname = "search/TNG+SIMBA_Mtot_beta_1_gamma_1"
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
mist.load_models(which_machine='vib+cls', fname=fname)
mist.test_on(sims="ASTRID", fname="10_m")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [73], in <module>
#       1 fname = "search/TNG+SIMBA_Mtot_beta_1_gamma_1"
#       2 mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
# ----> 3 mist.load_models(which_machine='vib+cls', fname=fname)
#       4 mist.test_on(sims="ASTRID", fname="10_m")
#
# File ~/ceph/CAMELS/MIEST/utils/mist_utils.py:83, in MIST.load_models(self, fname, which_machine, z_dim)
#      80 self.vib = VIB(self.input.shape[1], self.output.shape[1],
#      81                    z_dim)
#      82 self.cls = classifier(z_dim, num_models=self.num_sim)
# ---> 83 self.vib.load_state_dict(torch.load("./model/{}_vib.pt".format(fname)))
#      84 self.cls.load_state_dict(torch.load("./model/{}_cls.pt".format(fname)))
#      85 self.vib.to(self.device).eval()
#
# File /mnt/sw/nix/store/z6v265ivx5w6xbajay41vdfc0la8gla5-python-3.9.12-view/lib/python3.9/site-packages/torch/serialization.py:699, in load(f, map_location, pickle_module, **pickle_load_args)
#     696 if 'encoding' not in pickle_load_args.keys():
#     697     pickle_load_args['encoding'] = 'utf-8'
# --> 699 with _open_file_like(f, 'rb') as opened_file:
#     700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#
# File /mnt/sw/nix/store/z6v265ivx5w6xbajay41vdfc0la8gla5-python-3.9.12-view/lib/python3.9/site-packages/torch/serialization.py:231, in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
#     230     if _is_path(name_or_buffer):
# --> 231         return _open_file(name_or_buffer, mode)
#     232     else:
#     233         if 'w' in mode:
#
# File /mnt/sw/nix/store/z6v265ivx5w6xbajay41vdfc0la8gla5-python-3.9.12-view/lib/python3.9/site-packages/torch/serialization.py:212, in _open_file.__init__(self, name, mode)
#     211 def __init__(self, name, mode):
# --> 212     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/search/TNG+SIMBA_Mtot_beta_1_gamma_1_vib.pt'

# %%
fname = "avib/TNG+SIMBA+ASTRID"
mist = MIST(sim=["TNG","SIMBA","ASTRID"],field='Mtot', extended_L=False)
mist.train(which_machine='avib', fname=fname, beta=1e-1, gamma=1e0, test_auc=True)

# %%
fname = "avib/TNG+SIMBA+ASTRID"
mist = MIST(sim=["TNG","SIMBA","ASTRID"],field='Mtot', extended_L=False)
mist.train(which_machine='avib', fname=fname, beta=1e-1, gamma=1e0, test_auc=True)

# %%
fname = "avib/TNG+SIMBA"
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
mist.train(which_machine='avib', fname=fname, beta=1e1, gamma=1e-1)

# %%
fname = "search/TNG+SIMBA_beta_1.0_gamma_1.0"
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
mist.load_models(fname=fname)

# %%
mist.print_score()

# %%
mist.make_plots(fname=fname)

# %%
fname = "search/TNG+SIMBA+ASTRID_HI_beta_1.0_gamma_1.0"
mist = MIST(sim=["TNG","SIMBA",'ASTRID'],field='HI', extended_L=False)
mist.load_models(fname=fname)

# %%
mist.print_score()

# %%
mist.make_plots(fname=fname, figsize=(30,20))

# %%
mist.test_on(sims="ASTRID", fname="search/ASTRID_HI")

# %%
fname = "search/TNG+RAMSES_beta_1.0_gamma_1.0"
mist = MIST(sim=["TNG","GADGET"],field='Mtot', extended_L=False)
mist.load_models(fname=fname)
mist.test_on(sims="ASTRID", fname="search/RAMSES_test_dm")

# %%
mist.test_on(sims="ASTRID", fname="search/SIMBA_test")

# %%
mist.test_on(sims="ASTRID", fname="search/ASTRID_test")

# %%
mist.print_score()

# %%
mist.make_plots()

# %%
mist.test_on(sims="ASTRID", fname="TNG+SIMBA")

# %%
CE = nn.CrossEntropyLoss()

# %%
a = [[0,1],[0,1]]
b = [[1,0],[1,0]]

# %%
np.log10(1/2)

# %%
import copy
true        = mist.output_cls
fp          = copy.deepcopy(true)
fp[true==1] = 0
fp[true==0] = 1

# %%
CE(true,true)

# %%
CE(true,fp)*true.shape[0]

# %%
CE(torch.tensor(a,dtype=float),torch.tensor(b,dtype=float))

# %%
CE(torch.tensor(a,dtype=float),torch.tensor(b,dtype=float))

# %%
mist = MIST(sim=["TNG","SIMBA"],field='Xray', extended_L=False)
#mist.load_models()
mist.train(which_machine='vib+cls', fname="test_new4", beta=1e10, gamma=1e-1)

# %%
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
#mist.load_models()
mist.train(which_machine='vib+cls', fname="test_new5", beta=1e10, gamma=1e-1)

# %%
mist = MIST(sim=["TNG","SIMBA"],field='Mtot', extended_L=False)
#mist.load_models()
mist.train(which_machine='vib+cls', fname="test_new3", beta=1e10, gamma=1e2)

# %%
mist.save_models(fname="test_new2")

# %%
mist = MIST(sim=["GADGET","TNG"],field='Mtot', extended_L=False)
mist.load_models("GADGET+TNG")

# %%
mist.make_plots()

# %%
mist.test_on(sims="RAMSES", fname="GADGET+TNG_on_RAMSES")

# %%
mist.test_on(sims="ASTRID", fname="GADGET+TNG_on_ASTRIS")

# %%
mist.test_on(sims="SIMBA", fname="GADGET+TNG_on_SIMBA")

# %%
mist.test_on(sims="ASTRID", fname="TNG+SIMBA_on_ASTRID")

# %%
mist.print_score()

# %%
mist.print_score()

# %%
mist.make_plots()

# %%
mist.save_models()

# %%
mist = MIST(sim=["TNG","SIMBA"],field='Mtot')
mist.train()
#mist.load_models()

# %%
mist.print_score()

# %%
mist.make_plots()

# %% [markdown]
# ## Methods

# %%
def loader(field):
    fix = "_"+field
    coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nIllustrisTNG{}_for_vib_total.npy".format(fix))
    gcoef_avg = np.zeros((1000, coef.shape[1]))
    for i in range(1000):
        gcoef_avg[i,:] = coef[i*15:i*15+15,:].mean(axis=0)
    coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nSIMBA{}_for_vib_total.npy".format(fix))
    rcoef_avg = np.zeros((1000, coef.shape[1]))
    for i in range(1000):
        rcoef_avg[i,:] = coef[i*15:i*15+15,:].mean(axis=0)
    coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nAstrid{}_for_vib_total.npy".format(fix))
    acoef_avg = np.zeros((1000, coef.shape[1]))
    for i in range(1000):
        acoef_avg[i,:] = coef[i*15:i*15+15,:].mean(axis=0)
    coef = np.r_[gcoef_avg, rcoef_avg, acoef_avg]


    fparam = '/mnt/home/fvillaescusa/CAMELS/PUBLIC_RELEASE/CMD/2D_maps/data/params_IllustrisTNG.txt'
    gparams = np.loadtxt(fparam)
    gparams = gparams[:,:2] ## only Om and Sig8
    fparam = '/mnt/home/fvillaescusa/CAMELS/PUBLIC_RELEASE/CMD/2D_maps/data/params_SIMBA.txt'
    rparams = np.loadtxt(fparam)
    rparams = rparams[:,:2] ## only Om and Sig8
    fparam = "/mnt/home/fvillaescusa/CAMELS/Results/images_Astrid/params_LH_Astrid.txt" 
    aparams = np.loadtxt(fparam)
    aparams = aparams[:,:2] ## only Om and Sig8
    params  = np.r_[gparams, rparams, aparams]
    return coef, params

def loader_dmo(sim):
    fparam = "/mnt/ceph/users/fvillaescusa/Nbody_systematics/data/maps/maps_Gadget/params_Gadget.txt"
    gparams = np.loadtxt(fparam)
    gparams = gparams[:,:2] ## only Om and Sig8
    fparam = "/mnt/ceph/users/fvillaescusa/Nbody_systematics/data/maps/maps_Ramses/params_Ramses.txt"
    rparams = np.loadtxt(fparam)
    rparams = rparams[:,:2] ## only Om and Sig8
    params  = np.r_[gparams, rparams]

    coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nGadget_for_vib_total.npy")
    gcoef_avg = np.zeros((1000, coef.shape[1]))
    for i in range(1000):
        gcoef_avg[i,:] = coef[i*15:i*15+15,:].mean(axis=0)
    coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nRamses_for_vib_total.npy")
    rcoef_avg = np.zeros((1000, coef.shape[1]))
    for i in range(1000):
        rcoef_avg[i,:] = coef[i*15:i*15+15,:].mean(axis=0)
    coef = np.r_[gcoef_avg, rcoef_avg]
    if sim == "Gadget":
        return gcoef_avg, gparams
    if sim == "Ramses":
        return rcoef_avg, rparams
    if sim == "both":
        return coef, params

def make_dataset(coef,params):
    batch_size       = 100
    validation_split = .2
    shuffle_dataset  = True
    random_seed      = 42

    # Labelling for classification of simultions
    y   = torch.tensor(params,dtype=torch.float)[:,:2]


    X = torch.tensor(np.absolute(coef),dtype=torch.float)
    dataset      = data_utils.TensorDataset(X, y)
    dataset_size = len(dataset)
    indices      = list(range(dataset_size))
    split        = int(np.floor(validation_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(indices)
    train_indices, val_indices = indices[split:], indices[:split]

    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)

    train_loader  = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                               sampler=train_sampler)
    test_dataset      = data_utils.TensorDataset(X[val_indices], y[val_indices,:2])
    return train_loader, test_dataset

def print_score(test_dataset, vib, field):
    X, y            = test_dataset.tensors
    y_pred, y_sigma = vib(torch.tensor(X,dtype=torch.float).to(device))
    y_pred          = y_pred.cpu().detach().numpy()
    y               = y.cpu().detach().numpy()
    rele_om         = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
    rele_om         = rele_om.mean()
    r2_om           = sklearn.metrics.r2_score(y[:,0],y_pred[:,0])
    rele_sig        = np.abs(y[:,1]-y_pred[:,1])/y[:,1]
    rele_sig        = rele_sig.mean()
    r2_sig          = sklearn.metrics.r2_score(y[:,1],y_pred[:,1])

    #print(rele_om)
    print("{}: Reletive Error=({:.3f}, {:.3f}), R2 score=({:.3f}, {:.3f})"\
          .format(field,rele_om,rele_sig,r2_om,r2_sig))

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# Define a simple linear regression model
class LinearRegression(nn.Module):
    def __init__(self, input_shape, output_shape):
        super(LinearRegression, self).__init__()
        self.linear = nn.Sequential(
            nn.Linear(input_shape,1024),
            nn.ReLU(),
            nn.LayerNorm(1024),
            nn.Linear(1024,512),
            nn.ReLU(),
            nn.LayerNorm(512),
            nn.ReLU(),
            nn.Linear(512, output_shape)
        )

    def forward(self, x):
        return self.linear(x)

# %%
device='cuda'
coef, params = loader('Mtot')
train_loader, test_dataset = make_dataset(coef, params)

# %%
# Define the model, loss function, and optimizer
input_shape  = 3105
output_shape = 2
model = LinearRegression(input_shape, output_shape)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Train the model
num_epochs = 1000
for epoch in range(num_epochs):
    for _, (X,y) in enumerate(train_loader):
        X       = X.to(device)
        y       = y.float().to(device)

        # Forward pass
        y_pred = model(x_train)
        loss = criterion(y_pred, y_train)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Print progress
    if (epoch+1) % 100 == 0:
        print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [17], in <module>
#      10 for epoch in range(num_epochs):
#      11     for _, (X,y) in enumerate(train_loader):
# ---> 12         X       = X.to(device)
#      13         y       = y.float().to(device)
#      15         # Forward pass
#
# File /mnt/sw/nix/store/z6v265ivx5w6xbajay41vdfc0la8gla5-python-3.9.12-view/lib/python3.9/site-packages/torch/cuda/__init__.py:216, in _lazy_init()
#     212     raise AssertionError(
#     213         "libcudart functions unavailable. It looks like you have a broken build?")
#     214 # This function throws if there's a driver initialization error, no GPUs
#     215 # are found or any other error occurs
# --> 216 torch._C._cuda_init()
#     217 # Some of the queued calls may reentrantly call _lazy_init();
#     218 # we need to just return without initializing in that case.
#     219 # However, we must not let any *other* threads in!
#     220 _tls.is_initializing = True
#
# RuntimeError: No CUDA GPUs are available

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Mtot'

coef, params = loader(field)
train_loader, test_dataset = make_dataset(coef, params)

vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %% [markdown]
# # Hydro to DM

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Mtot'

coef, params = loader(field)
train_loader, test_dataset = make_dataset(coef, params)
_ndr = VIB_NDR(input_shape, output_shape,z_dim, num_models=3)
_cls = classifier(z_dim, num_models=3)
total_loss, accuracy = train_vib_ndr(_ndr, _cls, train_loader, device, epochs,batch_size,test_dataset,beta=1)
#total_loss, accuracy = train_vib_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %%
gcoef, y = loader_dmo("Gadget")
vib = _ndr
vib.eval()
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
gcoef, y = loader_dmo("Ramses")

vib.eval()
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %% [markdown]
# # DM+Hydro

# %%
def make_dataset_dm(coef,params):
    batch_size       = 100
    validation_split = .2
    shuffle_dataset  = True
    random_seed      = 42

    # Labelling for classification of simultions
    y_params   = torch.tensor(params,dtype=torch.float)
    y          = torch.zeros((y_params.shape[0],y_params.shape[1]+int(y_params.shape[0]/1000)))
    y[:,:2]    = y_params
    y[0:1000   ,2] = 1.
    y[1000:2000,3] = 1.
    #y[2000:3000,4] = 1.
    #y[3000:4000,5] = 1.


    X = torch.tensor(np.absolute(coef),dtype=torch.float)
    dataset      = data_utils.TensorDataset(X, y)
    dataset_size = len(dataset)
    indices      = list(range(dataset_size))
    split        = int(np.floor(validation_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(indices)
    train_indices, val_indices = indices[split:], indices[:split]

    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(val_indices)

    train_loader  = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                               sampler=train_sampler)
    test_dataset      = data_utils.TensorDataset(X[val_indices], y[val_indices,:2])
    return train_loader, test_dataset

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
batch_size = 100
epochs = 3000

gcoef, gparams = loader_dmo("Gadget")
coef, params = loader("Mtot")

coefall = np.r_[coef, gcoef]
paramall = np.r_[params,gparams]

train_loader, test_dataset = make_dataset(coefall, paramall)
vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=True)
print_score(test_dataset,vib,field)

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
batch_size = 100
epochs = 3000

gcoef, gparams = loader_dmo("Gadget")
coef, params = loader("Mtot")

coefall = np.r_[coef[:1000,:], gcoef]
paramall = np.r_[params[:1000,:],gparams]

train_loader, test_dataset = make_dataset_dm(coefall, paramall)
_ndr = VIB_NDR(input_shape, output_shape,z_dim, num_models=2)
_cls = classifier(z_dim, num_models=2)
total_loss, accuracy = train_vib_ndr(_ndr, _cls, train_loader, device, epochs,batch_size,test_dataset,beta=1)
#total_loss, accuracy = train_vib_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
#print_score(test_dataset,vib,field)

# %%
x, y = coef, params
vib = _ndr
vib.eval()
y_pred, _ = vib(torch.tensor(x,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
x, y = loader_dmo("Gadget")
vib = _ndr
vib.eval()
y_pred, _ = vib(torch.tensor(x,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
x, y = loader_dmo("Ramses")

vib.eval()
y_pred, _ = vib(torch.tensor(x,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %% [markdown]
# # To SB28

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Mtot'

coef, params = loader(field)
train_loader, test_dataset = make_dataset(coef, params)
vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %%
coef, params = loader(field)

# %%
coef.shape

# %%
np.r_[coef, gcoef].shape

# %%
fparam = '/mnt/home/fvillaescusa/CAMELS/Sims/IllustrisTNG_SB28/CosmoAstroSeed_SB28.txt'
gparams = np.zeros((len(index),2))
count=0
with open(fparam,"r") as f:
    for i, line in enumerate(f.readlines()):
        if i in index:
            elem = line.split()
            gparams[count,0] = float(elem[1])
            gparams[count,1] = float(elem[2])
            count += 1
    
_coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nTNG_SB28_for_vib_total.npy")
gcoef = np.zeros((len(index), coef.shape[1]))
for i in range(len(index)):
    gcoef[i,:] = _coef[i*15:i*15+15,:].mean(axis=0)

# %%
vib.eval()
y=gparams
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Mtot'

coef, params = loader(field)

train_loader, test_dataset = make_dataset(np.r_[coef,gcoef], np.r_[params,gparams])
vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %%
vib.eval()
y=gparams
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %% [markdown]
# ## Other Fields

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'HI'

coef, params = loader(field)

train_loader, test_dataset = make_dataset(coef, params)
vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %%
fparam = '/mnt/home/fvillaescusa/CAMELS/Sims/IllustrisTNG_SB28/CosmoAstroSeed_SB28.txt'
gparams = np.zeros((len(index),2))
count=0
with open(fparam,"r") as f:
    for i, line in enumerate(f.readlines()):
        if i in index:
            elem = line.split()
            gparams[count,0] = float(elem[1])
            gparams[count,1] = float(elem[2])
            count += 1
    
_coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nTNG_SB28_{}_for_vib_total.npy".format(field))
gcoef = np.zeros((len(index), coef.shape[1]))
for i in range(len(index)):
    gcoef[i,:] = _coef[i*15:i*15+15,:].mean(axis=0)

# %%
vib.eval()
y=gparams
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Mgas'

coef, params = loader(field)

train_loader, test_dataset = make_dataset(coef, params)
vib = NDR(input_shape, output_shape,z_dim, num_models=3)
total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
print_score(test_dataset,vib,field)

# %%
fparam = '/mnt/home/fvillaescusa/CAMELS/Sims/IllustrisTNG_SB28/CosmoAstroSeed_SB28.txt'
gparams = np.zeros((len(index),2))
count=0
with open(fparam,"r") as f:
    for i, line in enumerate(f.readlines()):
        if i in index:
            elem = line.split()
            gparams[count,0] = float(elem[1])
            gparams[count,1] = float(elem[2])
            count += 1
    
_coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nTNG_SB28_{}_for_vib_total.npy".format(field))
gcoef = np.zeros((len(index), coef.shape[1]))
for i in range(len(index)):
    gcoef[i,:] = _coef[i*15:i*15+15,:].mean(axis=0)

# %%
vib.eval()
y=gparams
y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
y_pred = y_pred.cpu().detach().numpy()

rel = (y[:,0]-y_pred[:,0])/y[:,0]
bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))

fig = plt.figure(figsize=(10,5))
ideal1 = np.linspace(0.1,0.5,3)
ideal2 = np.linspace(0.6,1.0,3)
fig.add_subplot(1,2,1)
plt.scatter(y[:,0],y_pred[:,0])
plt.plot(ideal1,ideal1,"r")
fig.add_subplot(1,2,2)
plt.scatter(y[:,1],y_pred[:,1])
plt.plot(ideal2,ideal2,"r")

# %%
# Hyperparameters
beta   = 1e-3
input_shape  = 3105
output_shape = 2
learning_rate = 1e-3
decay_rate = 0.97
z_dim = 200
epochs = 3000
batch_size = 100
field =  'Vcdm'

fields =  ['Mgas','Mstar','HI','ne','Vcdm','Z','T']

for field in fields:
    coef, params = loader(field)

    train_loader, test_dataset = make_dataset(coef, params)
    vib = NDR(input_shape, output_shape,z_dim, num_models=3)
    total_loss, accuracy = train_ndr(vib, train_loader, device, epochs,batch_size,test_dataset, verbose=False)
    print_score(test_dataset,vib,field)


    fparam = '/mnt/home/fvillaescusa/CAMELS/Sims/IllustrisTNG_SB28/CosmoAstroSeed_SB28.txt'
    gparams = np.zeros((len(index),2))
    count=0
    with open(fparam,"r") as f:
        for i, line in enumerate(f.readlines()):
            if i in index:
                elem = line.split()
                gparams[count,0] = float(elem[1])
                gparams[count,1] = float(elem[2])
                count += 1

    _coef = np.load("/mnt/home/yjo10/ceph/CAMELS/MIEST/data/wph_nTNG_SB28_{}_for_vib_total.npy".format(field))
    gcoef = np.zeros((len(index), coef.shape[1]))
    for i in range(len(index)):
        gcoef[i,:] = _coef[i*15:i*15+15,:].mean(axis=0)

    vib.eval()
    y=gparams
    y_pred, _ = vib(torch.tensor(gcoef,dtype=torch.float).to(device))
    y_pred = y_pred.cpu().detach().numpy()

    rel = (y[:,0]-y_pred[:,0])/y[:,0]
    bias = np.abs(y[:,0]-y_pred[:,0])/y[:,0]
    print(rel.mean(), bias.mean(), sklearn.metrics.r2_score(y[:,0],y_pred[:,0]))
