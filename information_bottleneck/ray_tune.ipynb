# %% [markdown]
# ## Imports

# %%
from functools import partial
import numpy as np
import torchvision
import torchvision.transforms as transforms
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
import torch

import sys,os
sys.path.append(os.path.abspath("/mnt/home/yjo10/ceph/CAMELS/MIEST/utils/"))
from imp import reload

import callback
reload(callback)
from callback import *
import ray_utils
reload(ray_utils)
from ray_utils import *
import vib_utils
reload(vib_utils)
from vib_utils import *
import mist_utils
reload(mist_utils)
from mist_utils import *
import ray_tune
reload(ray_tune)
from ray_tune import *

#warnings.filterwarnings('ignore')

# %%
field = 'HI';
sim   = 'TNG' #['TNG', 'SIMBA']
monopole = True;
projection=True
L = 4; dn = 0


fname = "TNG_{}_ray_test".format(field)
mist = MIST(sim=sim,field=field, normalization=True, monopole=monopole,
            average=False, data_type='wph',
            L=L, dn=dn, projection=projection,batch_size=16)
params =  {
    'which_machine':'vib',
    'trainset'     : mist.train_loader,
    'validset'     : mist.val_dataset,
    'num_sim'      : 1,
    'max_epoch'    : 100,
    'input_shape'  : mist.input.shape[1],
    'output_shape' : mist.output.shape[1],
    'patience'     : 50,
}
ray.init(runtime_env={"py_modules": [ray_utils]},ignore_reinit_error=True)
main(num_samples=10, gpus_per_trial=1, params=params)
# Out:
# 2023-04-18 20:27:38,699	INFO worker.py:1382 -- Calling ray.init() again after it has already been called.
# 2023-04-18 20:27:38,700	INFO registry.py:106 -- Detected unknown callable for trainable. Converting to class.
# ERROR! Session/line number was not unique in database. History logging moved to new session 1966
# 2023-04-18 20:27:39,936	WARNING worker.py:1866 -- Warning: The actor ImplicitFunc is very large (13 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# == Status ==
# Current time: 2023-04-18 20:27:40 (running for 00:00:01.13)
# Memory usage on this node: 86.0/754.5 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# ...
