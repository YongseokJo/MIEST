# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from collections import defaultdict

import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.utils.data as data_utils
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso
import sklearn
from torch.utils.data.sampler import SubsetRandomSampler

import sys,os
sys.path.append(os.path.abspath("/mnt/home/yjo10/ceph/CAMELS/MIEST/utils/"))
from imp import reload 
# Change in mymodule/'
import vib_utils
reload(vib_utils)
from vib_utils import *
import mist_utils
reload(mist_utils)
from mist_utils import *

import warnings
warnings.filterwarnings('ignore')

# Device Config
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = 'cpu' # temporarily
# Fix random seeds for reproducibility
seed = 73
#torch.manual_seed(seed)
#np.random.seed(seed)a
import sys,os 
import matplotlib.pyplot as plt
import numpy as np
sys.path.append(os.path.abspath("/mnt/home/yjo10/ceph/myutils/"))

from plt_utils import generateAxesForMultiplePlots, remove_inner_axes
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import chi2_contingency
import optuna

# %%
sim  = ['TNG','SIMBA']
field = 'T'
mist = MIST(sim=sim, field=field, batch_size=128, 
            data_type = 'image',
            normalization=True,
            monopole = True,
            device=device)
base_lr = 0.00035450334707527;
max_lr  = 1e-9;
beta    = 0;
gamma   = 0;
z_dim   = 858;
hidden  = 11;
wd      = 1.435527794760265e-05;
dr      = 0.15537182776936576;
success = mist.train(epochs=200,verbose=True, 
                     learning_rate=base_lr, max_lr=max_lr,
                     which_machine="separate_test", 
                     fname='seperate_test',
                     beta=beta, gamma=gamma,
                     z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
                     save_plot=True, save_model=False,
                    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <module>
#       1 sim  = ['TNG','SIMBA']
#       2 field = 'T'
# ----> 3 mist = MIST(sim=sim, field=field, batch_size=128,
#       4             data_type = 'image',
#       5             normalization=True,
#       6             monopole = True,
#       7             device=device)
#       8 base_lr = 0.00035450334707527;
#       9 max_lr  = 1e-9;
#
# File ~/ceph/CAMELS/MIEST/utils/mist_utils.py:63, in MIST.__init__(self, sim, field, batch_size, L, dn, data_type, proc_imag, normalization, monopole, projection, use_only_om, use_only_sig, guide_output, average, device)
#      60         print("Turning off average...")
#      61         self.average = False
# ---> 63 self.input, self.output = self.load_data()
#      65 self.make_train_set()
#
# ...

# %%
sim  = ['TNG','SIMBA']
field = 'T'
mist = MIST(sim=sim, field=field, batch_size=128, 
            data_type = 'image',
            normalization=True,
            monopole = True,
            device=device)
base_lr = 0.00035450334707527;
max_lr  = 1e-9;
beta    = 0;
gamma   = 0;
z_dim   = 858;
hidden  = 11;
wd      = 1.435527794760265e-05;
dr      = 0.15537182776936576;
success = mist.train(epochs=200,verbose=True, 
                     learning_rate=base_lr, max_lr=max_lr,
                     which_machine="separate_test", 
                     fname='seperate_test',
                     beta=beta, gamma=gamma,
                     z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
                     save_plot=True, save_model=False,
                    )

# %%
sim  = ['TNG','SIMBA']
field = 'HI'
mist = MIST(sim=sim, field=field, batch_size=200, 
            data_type = 'image',
            normalization=True,
            monopole = True,
            device=device)
base_lr = 1e-4;
max_lr  = 1e-9;
beta    = 0;
gamma   = 0;
z_dim   = 858;
hidden  = 8;
wd      = 1.435527794760265e-05;
dr      = 0.15537182776936576;
success = mist.train(epochs=200,verbose=True, 
                     learning_rate=base_lr, max_lr=max_lr,
                     which_machine="cnn_enc_dec", 
                     fname='vib_cnn+cls_test',
                     beta=beta, gamma=gamma, channels=1,
                     z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
                     save_plot=True, save_model=False,
                    )
# Out:
# epoch 0   | loss: -6.30201 | Om_m: 0.4909   | sig8: 0.37379  | auc: 0.51611  |||  val_loss: -3.73266  | val_Om_m: 0.25091  | val_sig8: 0.2647   | val auc: 0.62161
# 68314063360
# 68314063360
# epoch 1   | loss: -7.71247 | Om_m: 0.30875  | sig8: 0.23177  | auc: 0.66378  |||  val_loss: -4.61057  | val_Om_m: 0.17786  | val_sig8: 0.18143  | val auc: 0.75453
# 68314063360
# 68314063360
# epoch 2   | loss: -8.82537 | Om_m: 0.22501  | sig8: 0.16687  | auc: 0.65297  |||  val_loss: -5.05169  | val_Om_m: 0.13152  | val_sig8: 0.12321  | val auc: 0.55462
# 68314063360
# 68314063360
# epoch 3   | loss: -9.32838 | Om_m: 0.20207  | sig8: 0.14227  | auc: 0.76561  |||  val_loss: -5.10192  | val_Om_m: 0.13715  | val_sig8: 0.11708  | val auc: 0.81394
# 68314063360
# 68314063360
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <module>
#      14 wd      = 1.435527794760265e-05;
# ...

# %%
success

# %%
sim  = ['TNG','SIMBA']
field = 'Mtot'
mist = MIST(sim=sim, field=field, batch_size=50, 
            data_type = 'image',
            normalization=True,
            monopole = True,
            device=device)
base_lr = 0.00035450334707527;
max_lr  = 1e-9;
beta    = 0;
gamma   = 0;
z_dim   = 858;
hidden  = 6;
wd      = 1.435527794760265e-05;
dr      = 0.15537182776936576;
success = mist.train(epochs=200,verbose=True,
                     learning_rate=base_lr, max_lr=max_lr,
                     which_machine="cnn_enc_dec", 
                     fname='vib_cnn+cls_test',
                     beta=beta, gamma=gamma, channels=1,
                     z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
                     save_plot=True, save_model=False,
                    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <module>
#      14 wd      = 1.435527794760265e-05;
#      15 dr      = 0.15537182776936576;
# ---> 16 success = mist.train(epochs=200,verbose=True,
#      17                      learning_rate=base_lr, max_lr=max_lr,
#      18                      which_machine="cnn_enc_dec",
#      19                      fname='vib_cnn+cls_test',
#      20                      beta=beta, gamma=gamma, channels=1,
#      21                      z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
#      22                      save_plot=True, save_model=False,
#      23                     )
#
# ...

# %%
sim  = ['TNG','SIMBA']
field = ['HI','Vcdm']
mist = MIST(sim=sim, field=field, batch_size=128, 
            data_type = 'image',
            normalization=True,
            monopole = True,
            device=device)
base_lr = 0.00035450334707527;
max_lr  = 1e-9;
beta    = 0;
gamma   = 0;
z_dim   = 858;
hidden  = 11;
wd      = 1.435527794760265e-05;
dr      = 0.15537182776936576;
success = mist.train(epochs=200,verbose=True, 
                     learning_rate=base_lr, max_lr=max_lr,
                     which_machine="vib_cnn+cls", 
                     fname='vib_cnn+cls_test',
                     beta=beta, gamma=gamma, channels=len(field),
                     z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
                     save_plot=True, save_model=False,
                    )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [5], in <module>
#      14 wd      = 1.435527794760265e-05;
#      15 dr      = 0.15537182776936576;
# ---> 16 success = mist.train(epochs=200,verbose=True,
#      17                      learning_rate=base_lr, max_lr=max_lr,
#      18                      which_machine="vib_cnn+cls",
#      19                      fname='vib_cnn+cls_test',
#      20                      beta=beta, gamma=gamma, channels=len(field),
#      21                      z_dim=z_dim, hidden1=hidden, dr=dr,wd=wd,
#      22                      save_plot=True, save_model=False,
#      23                     )
#
# ...

# %%
mist.make_plots_cnn(fname='cnn_test')
mist.test_on_cnn('ASTRID', show_score=True)
# Out:
# $\Omega_m$: MSE=0.002, % error=13.597%, R2 score=0.839,chi2=8.270, bias=-0.044
# $\sigma_8$: MSE=0.028, % error=16.585%, R2 score=-1.091,chi2=65.972, bias=0.107
